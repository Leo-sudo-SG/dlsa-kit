# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))
from preprocess import preprocess_cumsum

# %%
returns = np.load('C:/Users/leotr/dlsa-kit/residuals/ipca_normalized/IPCA_DailyOOSresiduals_0_factors_420_initialMonths_240_window_12_reestimationFreq_0.01_cap.npy\IPCA_DailyOOSresiduals_0_factors_420_initialMonths_240_window_12_reestimationFreq_0.01_cap.npy')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\leotr\AppData\Local\Temp\ipykernel_3060\3859645830.py:1: SyntaxWarning: invalid escape sequence '\I'
#   returns = np.load('C:/Users/leotr/dlsa-kit/residuals/ipca_normalized/IPCA_DailyOOSresiduals_0_factors_420_initialMonths_240_window_12_reestimationFreq_0.01_cap.npy\IPCA_DailyOOSresiduals_0_factors_420_initialMonths_240_window_12_reestimationFreq_0.01_cap.npy')

# %%
data = np.load('C:/Users/leotr/dlsa-kit/residuals/ipca_normalized/IPCA_DailyOOSresiduals_5_factors_420_initialMonths_240_window_12_reestimationFreq_0.01_cap.npy\IPCA_DailyOOSresiduals_5_factors_420_initialMonths_240_window_12_reestimationFreq_0.01_cap.npy')
mask = np.load('C:/Users/leotr/dlsa-kit/residuals/superMask.npy')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\leotr\AppData\Local\Temp\ipykernel_3060\3645281640.py:1: SyntaxWarning: invalid escape sequence '\I'
#   data = np.load('C:/Users/leotr/dlsa-kit/residuals/ipca_normalized/IPCA_DailyOOSresiduals_5_factors_420_initialMonths_240_window_12_reestimationFreq_0.01_cap.npy\IPCA_DailyOOSresiduals_5_factors_420_initialMonths_240_window_12_reestimationFreq_0.01_cap.npy')

# %%
chosen_assets = np.where(mask)[0]

# %%
data.shape
# Out:
# (4781, 9483)

# %%
residuals_filtered = data[:, chosen_assets]

# %%
residuals_filtered.shape
# Out:
# (4781, 2434)

# %%
T_start = max(0, residuals_filtered.shape[0] - 1200)  # Last ~5 years
residuals_subset = residuals_filtered[T_start:, :]

# %%
lookback = 30
windows, idxs_selected = preprocess_cumsum(residuals_subset, lookback)

# %%
windows.shape
# Out:
# (1170, 2434, 30)
