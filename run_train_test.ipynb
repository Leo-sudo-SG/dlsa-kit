# %%
# !python run_train_test.py -c configs/cnntransformer-full.yaml
# Out:
# python3: can't open file '/content/run_train_test.py': [Errno 2] No such file or directory

# %%
# !git clone https://github.com/Leo-sudo-SG/dlsa-kit.git
# Out:
# Cloning into 'dlsa-kit'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 110 (delta 13), reused 38 (delta 9), pack-reused 58 (from 1)
# Receiving objects: 100% (110/110), 792.30 MiB | 16.38 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# Updating files: 100% (53/53), done.

# %%
# !pip install -r dlsa-kit/requirements.txt

# %%
# !ls
# Out:
# '=0.6.0'   '=2.1.0,torch-sparse'  '=2.3.0,torch-scatter'   sample_data
# '=2.1.0'   '=2.3.0'		   dlsa-kit
# '=2.1.0,'  '=2.3.0,'		   logs

# %%
# Out:
# fatal: not a git repository (or any of the parent directories): .git
